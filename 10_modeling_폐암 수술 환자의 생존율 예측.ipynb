# %%
#딥러닝을 구동하는 데 필요한 케라스 함수 호출
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#필요한 라이브러리 호출
import numpy as np
import tensorflow as tf

# %%
#실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분
np.random.seed(3)
tf.random.set_seed(3)

#준비된 수술 환자 데이터를 불러옴
Data_set = np.loadtxt("../home/ThoraricSurgery.csv", delimiter=",")

#환자의 기록과 수술 결과를 X와 Y로 구분하여 저장
X = Data_set[:,0:17]
Y=Data_set[:,17]

#딥러닝 구조를 결정(모델을 설정하고 실행하는 부분)
model = Sequential()  #Sequential 함수를 통해 퍼셉트론의 층 구현
model.add(Dense(30, input_dim=17, activation='relu')) #Dense : 구조 결정, 30 : 해당 층의 노드 수, input_dim : 입력 데이터 수, activation : 활성화함수 
model.add(Dense(1,activation='sigmoid'))

# %%
#딥러닝 실행
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#model.complie(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X,Y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8517
# Epoch 2/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3741 - accuracy: 0.8706
# Epoch 3/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8346
# Epoch 4/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.8393
# Epoch 5/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.8624
# Epoch 6/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3673 - accuracy: 0.8608
# Epoch 7/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4283 - accuracy: 0.8470
# Epoch 8/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3929 - accuracy: 0.8545
# Epoch 9/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3357 - accuracy: 0.8610
# Epoch 10/100
# ...
